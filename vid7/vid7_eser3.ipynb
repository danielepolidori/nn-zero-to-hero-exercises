# %% [markdown]
# # Pre-training

# %%
import torch
import torch.nn as nn
from torch.nn import functional as F

# hyperparameters
batch_size = 16 # how many independent sequences will we process in parallel?
block_size = 32 # what is the maximum context length for predictions?
max_iters = 5000
eval_interval = 100
learning_rate = 1e-3
device = 'cuda' if torch.cuda.is_available() else 'cpu'
eval_iters = 200
n_embd = 64
n_head = 4
n_layer = 4
dropout = 0.0
# ------------

torch.manual_seed(1337)

# %%
from google.colab import drive
drive.mount('/content/gdrive')

text_amazon = open('gdrive/MyDrive/Colab Notebooks/makemore/Cell_Phones_and_Accessories_5.txt', 'r', encoding='utf-8').read()
text = text_amazon

print("length of dataset in characters: ", len(text))
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# length of dataset in characters:  141690237

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %%
# data loading
def get_batch(split):
    # generate a small batch of data of inputs x and targets y
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        B,T,C = x.shape
        k = self.key(x)   # (B,T,C)
        q = self.query(x) # (B,T,C)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * C**-0.5 # (B, T, C) @ (B, C, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,C)
        out = wei @ v # (B, T, T) @ (B, T, C) -> (B, T, C)
        return out

class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(n_embd, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1)
        out = self.dropout(self.proj(out))
        return out

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)

class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x))
        x = x + self.ffwd(self.ln2(x))
        return x

# super simple bigram model
class BigramLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        # each token directly reads off the logits for the next token from a lookup table
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        # idx is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            idx_cond = idx[:, -block_size:]
            # get the predictions
            logits, loss = self(idx_cond)
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)
            # sample from the distribution
            idx_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            # append sampled index to the running sequence
            idx = torch.cat((idx, idx_next), dim=1) # (B, T+1)
        return idx

model = BigramLanguageModel()
m = model.to(device)
# print the number of parameters in the model
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')
# Out:
# 0.213599 M parameters

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
context = torch.zeros((1, 1), dtype=torch.long, device=device)
print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# step 0: train loss 4.7645, val loss 4.7593
# step 100: train loss 2.6602, val loss 2.6959
# step 200: train loss 2.3921, val loss 2.4647
# step 300: train loss 2.2253, val loss 2.3302
# step 400: train loss 2.0908, val loss 2.2024
# step 500: train loss 1.9970, val loss 2.1056
# step 600: train loss 1.9199, val loss 2.0609
# step 700: train loss 1.9346, val loss 2.0225
# step 800: train loss 1.8470, val loss 1.9632
# step 900: train loss 1.7975, val loss 1.8909
# step 1000: train loss 1.7673, val loss 1.8763
# step 1100: train loss 1.6981, val loss 1.8274
# step 1200: train loss 1.7211, val loss 1.7965
# step 1300: train loss 1.6841, val loss 1.7898
# step 1400: train loss 1.6587, val loss 1.7716
# step 1500: train loss 1.6592, val loss 1.7729
# step 1600: train loss 1.6302, val loss 1.7456
# step 1700: train loss 1.6070, val loss 1.7191
# step 1800: train loss 1.5853, val loss 1.6885
# step 1900: train loss 1.5849, val loss 1.6912
# step 2000: train loss 1.5611, val loss 1.6593
# step 2100: train loss 1.5570, val loss 1.6493
# step 2200: train loss 1.5476, val loss 1.6557
# step 2300: train loss 1.5502, val loss 1.6209
# step 2400: train loss 1.5315, val loss 1.6405
# step 2500: train loss 1.5225, val loss 1.6236
# step 2600: train loss 1.5135, val loss 1.6152
# step 2700: train loss 1.5115, val loss 1.5899
# step 2800: train loss 1.4897, val loss 1.5849
# step 2900: train loss 1.4847, val loss 1.5553
# step 3000: train loss 1.4812, val loss 1.5665
# step 3100: train loss 1.4664, val loss 1.5624
# step 3200: train loss 1.4886, val loss 1.5806
# step 3300: train loss 1.4545, val loss 1.5506
# step 3400: train loss 1.4494, val loss 1.5458
# step 3500: train loss 1.4638, val loss 1.5377
# step 3600: train loss 1.4402, val loss 1.5649
# step 3700: train loss 1.4609, val loss 1.5383
# step 3800: train loss 1.4221, val loss 1.5318
# step 3900: train loss 1.4373, val loss 1.5177
# step 4000: train loss 1.4260, val loss 1.5169
# step 4100: train loss 1.4293, val loss 1.5269
# step 4200: train loss 1.4161, val loss 1.5254
# step 4300: train loss 1.4138, val loss 1.4971
# step 4400: train loss 1.4107, val loss 1.4926
# step 4500: train loss 1.3943, val loss 1.4991
# step 4600: train loss 1.3964, val loss 1.4804
# step 4700: train loss 1.4038, val loss 1.5042
# step 4800: train loss 1.4019, val loss 1.4977
# step 4900: train loss 1.4133, val loss 1.4945
# step 4999: train loss 1.3830, val loss 1.4876
#
# {"reviewTime": "01 6, 50014"}
# {"reviewerID": "A1IX81UMMVANEM", "asin": "B0085TIT3U", "unixReviewTime": 1375640030000, "reviewTime": "06 19, 2013"}
# {"reviewerID": "ABFF193Z0TAAZTPK", "asin": "B009FCX50", "helpful": [0, 2], "reviewText": "I conver, but it's loveran", "helpful": [0, 0], "reviewText": "This power ofter.", "overall": 5.0, "summary": "Furnixisy phones on a $1%. This in with all the rurating  vooay -)25 evers: protectived a with and Maven too of reslied scaning noisted ontroped abim cared a Just Repener of Put formontruct prop and oftely net I was acelly for sinnewain to pirsions.  More, is sounds, it's at whink lorg.  I was af sinstly *I've a nice 1 TThay tevers S9201 Deven and quility I'm have batteonifiroly", "unixReviewTime": 013672600, "reviewT the brain and lof you have to the battery excan on alloter IUVD", "unixReviewTime": 13836302720000, "reviewTime": "09 221, 2014"}
# {"reviewerID": "A2E02W3EFPHPZBM", "asin": "B009O6TD2U", "reviewerName": "The bonng", "helpful": [1, 22], "reviewText": "I raded the etwistes and away and hippe coontrated I am with for iS Dmorsing Great 10%01B 6744 Hese**!!So fart too converage sup Enots.9 kecause.  Iad main comp", "helpful": [0, 0], "reviewText": "but rettor anound withe oney this fits short succhined to tay the battery tour PlePicallt the least ared any iPhone though it touch you spick put allow, the eay secuse ofnce the I raber have styling eit dit is ceprocesiting, quality7212a lessids and have teluch good be ones more it ay props.The comfallester", "helpful": [1, 1], "reviewText": "The protected is not replaced that I befeliple - to recordiding on 1244000%, "summary": "Though it is for a I get the littlings your loown eit one but work its sincronedly lower for and to hugse.", "overall": 5.0, "summary": "ANO! Theck because", "unixReviewTime": 137766927416000, "reviewTime": "01 15, 2012"}
# {"reviewerID": "A28DONBOTCOBB2", "92", "asin": "B005YGHNTY", "helpful": [0, 2], "reviewText": "I coulds and to secuven years ad

# %% [markdown]
# # Training

# %%
# !wget https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
with open('input.txt', 'r', encoding='utf-8') as f:
    text = f.read()
# Out:
# --2023-10-27 18:12:03--  https://raw.githubusercontent.com/karpathy/char-rnn/master/data/tinyshakespeare/input.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘input.txt.3’
#
# input.txt.3         100%[===================>]   1.06M  --.-KB/s    in 0.07s
#
# 2023-10-27 18:12:03 (14.4 MB/s) - ‘input.txt.3’ saved [1115394/1115394]

# %%
# here are all the unique characters that occur in this text
chars = sorted(list(set(text)))
vocab_size = len(chars)
# create a mapping from characters to integers
stoi = { ch:i for i,ch in enumerate(chars) }
itos = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [stoi[c] for c in s] # encoder: take a string, output a list of integers
decode = lambda l: ''.join([itos[i] for i in l]) # decoder: take a list of integers, output a string

# Train and test splits
data = torch.tensor(encode(text), dtype=torch.long)
n = int(0.9*len(data)) # first 90% will be train, rest val
train_data = data[:n]
val_data = data[n:]

# %% [markdown]
# Smaller number of steps and lower learning rate.

# %%
max_iters = 5000     #5000
learning_rate = 1e-4 #1e-3

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

for iter in range(max_iters):

    # every once in a while evaluate the loss on train and val sets
    if iter % eval_interval == 0 or iter == max_iters - 1:
        losses = estimate_loss()
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()

# generate from the model
#context = torch.zeros((1, 1), dtype=torch.long, device=device)
#print(decode(m.generate(context, max_new_tokens=2000)[0].tolist()))
# Out:
# step 0: train loss 5.0907, val loss 5.2162
# step 100: train loss 3.2664, val loss 3.2888
# step 200: train loss 2.9402, val loss 2.9622
# step 300: train loss 2.7586, val loss 2.7813
# step 400: train loss 2.6361, val loss 2.6536
# step 500: train loss 2.5515, val loss 2.5686
# step 600: train loss 2.4826, val loss 2.5025
# step 700: train loss 2.4273, val loss 2.4511
# step 800: train loss 2.3873, val loss 2.4117
# step 900: train loss 2.3546, val loss 2.3707
# step 1000: train loss 2.3150, val loss 2.3340
# step 1100: train loss 2.2898, val loss 2.3149
# step 1200: train loss 2.2718, val loss 2.2841
# step 1300: train loss 2.2470, val loss 2.2640
# step 1400: train loss 2.2209, val loss 2.2456
# step 1500: train loss 2.1997, val loss 2.2366
# step 1600: train loss 2.1839, val loss 2.2269
# step 1700: train loss 2.1642, val loss 2.2067
# step 1800: train loss 2.1570, val loss 2.1825
# step 1900: train loss 2.1377, val loss 2.1852
# step 2000: train loss 2.1225, val loss 2.1645
# step 2100: train loss 2.1074, val loss 2.1540
# step 2200: train loss 2.1023, val loss 2.1537
# step 2300: train loss 2.0822, val loss 2.1412
# step 2400: train loss 2.0796, val loss 2.1256
# step 2500: train loss 2.0728, val loss 2.1320
# step 2600: train loss 2.0603, val loss 2.1184
# step 2700: train loss 2.0591, val loss 2.1120
# step 2800: train loss 2.0429, val loss 2.1044
# step 2900: train loss 2.0265, val loss 2.0925
# step 3000: train loss 2.0269, val loss 2.0848
# step 3100: train loss 2.0131, val loss 2.0850
# step 3200: train loss 2.0075, val loss 2.0817
# step 3300: train loss 2.0047, val loss 2.0777
# step 3400: train loss 1.9970, val loss 2.0637
# step 3500: train loss 1.9960, val loss 2.0593
# step 3600: train loss 1.9891, val loss 2.0646
# step 3700: train loss 1.9825, val loss 2.0612
# step 3800: train loss 1.9799, val loss 2.0529
# step 3900: train loss 1.9701, val loss 2.0500
# step 4000: train loss 1.9647, val loss 2.0366
# step 4100: train loss 1.9544, val loss 2.0487
# step 4200: train loss 1.9548, val loss 2.0437
# step 4300: train loss 1.9372, val loss 2.0276
# step 4400: train loss 1.9326, val loss 2.0364
# step 4500: train loss 1.9391, val loss 2.0390
# step 4600: train loss 1.9354, val loss 2.0322
# step 4700: train loss 1.9231, val loss 2.0076
# step 4800: train loss 1.9194, val loss 2.0200
# step 4900: train loss 1.9182, val loss 2.0249
# step 4999: train loss 1.9125, val loss 2.0153
